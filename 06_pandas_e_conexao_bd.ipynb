# %% [markdown]
# ### Anotações da aula de 09/02/2022
# By: [George Pontes](https://github.com/georgecnha)

# %% [markdown]
# # PARTE 1
#
# A primeira parte da aula demonstrou algumas funções que podem se utilizadas para limpeza de dados. Isto foi feito com esse [dataset](https://s3-sa-east-1.amazonaws.com/lcpi/24082a68-969b-48bf-aecc-4fd02ee646fc.csv)

# %%
import pandas as pd

df= pd.read_csv('https://s3-sa-east-1.amazonaws.com/lcpi/24082a68-969b-48bf-aecc-4fd02ee646fc.csv')
df
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %% [markdown]
# ## Algumas funções do **Pandas**

# %% [markdown]
# ### `pd.Dataframe.isna()`

# %% [markdown]
# Detect missing values.
#
# Return a boolean same-sized object indicating if the values are NA. NA values, such as None or numpy.NaN, gets mapped to True values. Everything else gets mapped to False values. Characters such as empty strings `''` or `numpy.inf` are not considered NA values (unless you set `pandas.options.mode.use_inf_as_na = True`).

# %%
df.isna()
# Out:
#      Invoice ID   Date   Time  Gender  Location   City  Member  Category  \
# 0         False  False  False   False     False  False   False     False
# 1         False  False  False   False     False  False   False     False
# 2         False  False  False   False     False  False   False     False
# 3         False  False  False   False     False  False   False     False
# 4         False  False  False   False     False  False   False     False
# ..          ...    ...    ...     ...       ...    ...     ...       ...
# 995       False  False  False   False     False  False   False     False
# 996       False  False  False   False     False  False   False     False
# 997       False  False  False   False     False  False   False     False
# 998       False  False  False   False     False  False   False     False
# 999       False  False  False   False     False  False   False     False
#
#      Price  Quantity  Total  Payment  Rating
# 0    False     False  False    False   False
# ...

# %% [markdown]
# ### `DataFrame.duplicated(subset=None, keep='first')`
#
# Return boolean Series denoting duplicate rows.

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# ### `DataFrame.drop()`
#
# Drop specified labels from rows or columns.

# %%
df.drop(columns= ['Date','Time'] )
# Out:
#      Invoice ID  Gender     Location     City Member   Category  Price  \
# 0     460489604    Male   Brookfield  NewYork    Yes  Groceries     30
# 1     471006167  Female  Water tower  Chicago    Yes    Fashion     35
# 2     411909258    Male  Water tower  Chicago     No   Clothing     57
# 3     487313402  Female    Park lane   Dallas    Yes   Sporting     89
# 4     197763430  Female    Park lane   Dallas     No      Books     82
# ..          ...     ...          ...      ...    ...        ...    ...
# 995   818829599    Male    Park lane   Dallas     No  Groceries     31
# 996   556589713    Male  Water tower  Chicago    Yes  Groceries      3
# 997    82324424    Male   Brookfield  NewYork     No   Clothing     71
# 998   783661702  Female   Brookfield  NewYork     No   Clothing     89
# 999   759171975  Female  Water tower  Chicago    Yes   Clothing     31
#
#      Quantity  Total Payment  Rating
# 0           1     30    Cash       2
# 1           5    175    Card       3
# ...

# %%
df.drop(labels= [3,4])
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# 6      99646662   3/4/2018  13:21    Male  Water tower  Chicago     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %% [markdown]
# ### `pd.Dataframe.dropna()`

# %% [markdown]
# Remove missing values.

# %%
df.dropna()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
df.loc[3,'Payment']= None #criando um valor None

# %%
df.dropna() #remove a linha inteira onde o None estava
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %% [markdown]
# ### `DataFrame.drop_duplicates()`
#
# Return DataFrame with duplicate rows removed.

# %%
df.drop_duplicates()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3     487313402  1/22/2018  13:38  Female    Park lane   Dallas    Yes
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %%
#fazendo uma linha se tornar uma duplicata de outra linha para demonstrar o método

df.loc[3]= df.loc[2]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Invoice ID       Date   Time  Gender     Location     City Member  \
# 0     460489604  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1     471006167  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2     411909258  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4     197763430  2/18/2018  15:31  Female    Park lane   Dallas     No
# 5     263634050   3/9/2018  17:55    Male   Brookfield  NewYork    Yes
# ..          ...        ...    ...     ...          ...      ...    ...
# 995   818829599  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996   556589713  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997    82324424   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998   783661702  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999   759171975  1/31/2018  10:13  Female  Water tower  Chicago    Yes
#
#       Category  Price  Quantity  Total Payment  Rating
# 0    Groceries     30         1     30    Cash       2
# ...

# %% [markdown]
# #### Maneiras de inserir dados no Dataframe

# %%
df.loc[999]= [None, None, None, None, None, None, None, None, None, None, None, None, None]
df
# Out:
#       Invoice ID       Date   Time  Gender     Location     City Member  \
# 0    460489604.0  1/25/2018  16:46    Male   Brookfield  NewYork    Yes
# 1    471006167.0  3/19/2018  16:48  Female  Water tower  Chicago    Yes
# 2    411909258.0  2/25/2018  13:33    Male  Water tower  Chicago     No
# 3    411909258.0  2/25/2018  13:33    Male  Water tower  Chicago     No
# 4    197763430.0  2/18/2018  15:31  Female    Park lane   Dallas     No
# ..           ...        ...    ...     ...          ...      ...    ...
# 995  818829599.0  3/26/2018  11:19    Male    Park lane   Dallas     No
# 996  556589713.0  2/20/2018  17:17    Male  Water tower  Chicago    Yes
# 997   82324424.0   2/6/2018  11:44    Male   Brookfield  NewYork     No
# 998  783661702.0  1/29/2018  15:44  Female   Brookfield  NewYork     No
# 999          NaN       None   None    None         None     None   None
#
#       Category  Price  Quantity  Total Payment  Rating
# ...

# %% [markdown]
# #### Transcrever uma coluna inteira (series) para uma lista do Python

# %%
df['Invoice ID'].tolist()
# Out:
# [460489604.0,
#  471006167.0,
#  411909258.0,
#  411909258.0,
#  197763430.0,
#  263634050.0,
#  99646662.0,
#  188869875.0,
#  325637547.0,
#  562942936.0,
#  388412668.0,
#  846531724.0,
#  149894432.0,
#  942406749.0,
#  547572603.0,
#  355981315.0,
#  397754805.0,
#  90524319.0,
#  542144906.0,
#  729486362.0,
#  619639105.0,
#  443198801.0,
#  761515143.0,
#  56578535.0,
#  834838148.0,
#  833288071.0,
#  508614950.0,
#  103072863.0,
#  355815500.0,
#  193855414.0,
#  600792216.0,
#  567867755.0,
#  597934753.0,
#  419033295.0,
#  8795029.0,
#  912473338.0,
#  209725428.0,
#  460044751.0,
#  191736512.0,
#  979973145.0,
#  43371182.0,
#  613811022.0,
#  673603546.0,
#  328132417.0,
#  325924536.0,
#  747705702.0,
#  450817216.0,
#  315624039.0,
#  888822600.0,
#  896399395.0,
#  20548577.0,
#  500850764.0,
#  466598448.0,
#  265371038.0,
#  175938157.0,
#  839600262.0,
#  885253494.0,
#  180545139.0,
#  227063423.0,
#  500777576.0,
#  426576006.0,
#  934647292.0,
# ...

# %% [markdown]
# ____________________

# %% [markdown]
# ____________________________________________________

# %% [markdown]
# # PARTE 2
# Na segunda parte da aula, foram demonstradas algumas funcionalidades do `pandasql`

# %% [markdown]
# ### pandasql
# Permite fazer queries em Dataframes do Pandas com linguagem SQL.

# %%
#Instalação

# !pip install -U pandasql

# %% [markdown]
# #### Usando PandaSQL pra fazer uma "query" em um Dataframe

# %%
from pandasql import PandaSQL

pdsql = PandaSQL()
query = "SELECT COUNT(City), City FROM df GROUP BY City"
df_final = pdsql(query)
print(df_final)
# Out:
#    COUNT(City)     City
# 0            0     None
# 1          328  Chicago
# 2          331   Dallas
# 3          340  NewYork

# %% [markdown]
# #### Como seria essa mesma "query" no Pandas

# %%
df.groupby(['City'])['City'].count()
# Out:
# City
# Chicago    328
# Dallas     331
# NewYork    340
# Name: City, dtype: int64

# %% [markdown]
# __________________________________________________________
#
# ___________________________________________________________

# %% [markdown]
# # PARTE 3
#
# Na terceira parte da aula foi demonstrada a conexão do python com bancos de dados.

# %% [markdown]
# ### sqlalchemy
# Desenvolvido para a linguagem de programação Python, o SQLAlchemy é um framework de mapeamento objeto-relacional SQL (ORM) de código aberto sobre a licença MIT.
#
# Sua utilização também visa retirar a necessidade do desenvolvedor de software em se preocupar com a linguagem SQL (geração dos comandos SQL) e com as conversões necessárias entre os diferentes tipos de dados, já que tudo isto fica a cargo do Framework ORM.
#
# Conseguimos utilizar banco de dados relacionais por meio de objetos escritos em Python, não se preocupando em como este BD está funcionando (relações, campos, etc), apenas mapeando sua estrutura.

# %%
# !pip install sqlalchemy

# %% [markdown]
# ### mysqlclient
# Responsável pela conexão de banco de dados MySQL em scripts Python.

# %%
#!pip install mysqlclient

# %% [markdown]
# ### psycopg2
# Cliente para postgreesql
# https://pypi.org/project/psycopg2/

# %%
# !pip install psycopg2

# %% [markdown]
# ____________________________________________________
# Banco de dados sugerido para instalação: MySQL.
#
# Jeito mais fácil de instalar: instale o [XAMPP](https://www.apachefriends.org/pt_br/index.html)

# %%
# Conexão com o BD

from sqlalchemy import create_engine
import pandas as pd
from pandasql import PandaSQL

# Modelo da URL da database
# engine = create_engine("dialect+driver://username:password@host:port/database)


# mysqlclient (a maintained fork of MySQL-Python)
# engine = create_engine("mysql+mysqldb://scott:tiger@localhost/foo")


# O que o prof escreveu para o engine  
# engine = create_engine("mysql+mysqldb://root:@localhost/test")

# Para quem vai usar o postgres
# engine create_engine('postgresql+psycopg2://user:password@hostname/database_name")
engine= create_engine("postgresql+psycopg2://postgres:021294@localhost/postgres")
connection = engine.connect()

# %%
#query="SELECT * FROM estado_cidade"
query="SELECT * FROM cardapio"
df = pd.read_sql(query, connection)
df
# Out:
#     cardapio_id         nome_item       nome_secao  preco
# 0             1     Cheeseburguer          Lanches   27.9
# 1             2        Hamburguer          Lanches   22.9
# 2             3          X-Salada          Lanches   25.9
# 3             4     Veggieburguer          Lanches   30.9
# 4             5           X-Bacon          Lanches   32.9
# 5             6      Batata Frita  Acompanhamentos    9.9
# 6             7  Batata Turbinada  Acompanhamentos   15.9
# 7             8       Onion Rings  Acompanhamentos   12.9
# 8             9           Nuggets  Acompanhamentos   14.9
# 9            10          Maionese           Molhos    3.0
# 10           11           Ketchup           Molhos    2.5
# 11           12          Mostarda           Molhos    2.5
# 12           13      Refrigerante          Bebidas    6.5
# 13           14              Suco          Bebidas    4.5
# 14           15           Cerveja          Bebidas   11.9
# ...

# %% [markdown]
# # Exercícios pós-aula

# %% [markdown]
# 1) Leve os dados AS_IS do Google Drive para o Banco de Dados Local (MySQL). Faça isso em um processo único, isto é, ao executar o código/notebook, ele deve ser capaz de ingerir esses dados
#
# 2) A partir do conjunto de dados, disponibilizado em: https://www.kaggle.com/code/aremoto/retail-sales-forecast/data, faça:
#
# Insira-os em um banco de dados
# Uma função que retorne a média de preços dos combustíveis e das temperaturas num determinado range de data.
# Ex.:
# ```python
# def funcao('fuel' or 'temperature', 'date')
# ```
